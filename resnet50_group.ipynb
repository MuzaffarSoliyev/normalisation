# %%
import torch
import torch.nn as nn
import torchvision as tv
import torch.optim as O

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print(torch.cuda.is_available())
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 0
# <torch.cuda.device object at 0x7ff77483fd68>
# 1
# Tesla T4

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    1.8 GB

# %%
import torch
import random
import numpy as np

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True

# %%
cifar100 = tv.datasets.CIFAR100

# %%
train_batch = 256
test_batch = 256

# %%
import torchvision.transforms as transforms
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343], std=[0.2673342858792401, 0.2564384629170883, 0.27615047132568404])
])

# Normalize test set same as training set without augmentation
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343], std=[0.2673342858792401, 0.2564384629170883, 0.27615047132568404])
])

# %%
trainset = tv.datasets.CIFAR100(root='./cifar100/train',
                                         train=True,
                                         download=True,
                                         transform=transform_train)
cifar100_train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=train_batch, shuffle=True, num_workers=4)

testset = tv.datasets.CIFAR100(root='./cifar100/test',
                                        train=False,
                                        download=True,
                                        transform=transform_test)
cifar100_test_loader = torch.utils.data.DataLoader(
    testset, batch_size=test_batch, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def conv3x3(in_channels, out_channels, stride=1):
    """3x3 kernel size with padding convolutional layer in ResNet BasicBlock."""
    return nn.Conv2d(
        in_channels=in_channels,
        out_channels=out_channels,
        kernel_size=3,
        stride=stride,
        padding=1,
        bias=False)


class BasicBlock(nn.Module):
    """Basic Block of ReseNet."""

    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        """Basic Block of ReseNet Builder."""
        super(BasicBlock, self).__init__()

        # First conv3x3 layer
        self.conv1 = conv3x3(in_channels, out_channels, stride)

        #  Batch Normalization
        self.bn1 = nn.GroupNorm(16,out_channels)

        # ReLU Activation Function
        self.relu = nn.ReLU(inplace=True)

        # Second conv3x3 layer
        self.conv2 = conv3x3(out_channels, out_channels)

        #  Batch Normalization
        self.bn2 = nn.GroupNorm(16,out_channels)

        # downsample for `residual`
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        """Forward Pass of Basic Block."""
        residual = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)

        if self.downsample is not None:
            residual = self.downsample(x)

        out += residual
        return out

class ResNet(nn.Module):
    """Residual Neural Network."""

    def __init__(self, block, duplicates, num_classes=100):
        """Residual Neural Network Builder."""
        super(ResNet, self).__init__()

        self.in_channels = 32
        self.conv1 = conv3x3(in_channels=3, out_channels=32)
        self.bn = nn.GroupNorm(8,32)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout2d(p=0.02)

        # block of Basic Blocks
        self.conv2_x = self._make_block(block, duplicates[0], out_channels=32)
        self.bn2_x = nn.GroupNorm(8,32)
        self.conv3_x = self._make_block(block, duplicates[1], out_channels=64, stride=2)
        self.bn3_x = nn.GroupNorm(16,64)
        self.conv4_x = self._make_block(block, duplicates[2], out_channels=128, stride=2)
        self.bn4_x = nn.GroupNorm(32,128)
        self.conv5_x = self._make_block(block, duplicates[3], out_channels=256, stride=2)
        self.bn5_x = nn.GroupNorm(64,256)

        self.maxpool = nn.MaxPool2d(kernel_size=4, stride=1)
        self.fc_layer = nn.Linear(256, num_classes)

        # initialize weights
        # self.apply(initialize_weights)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal(m.weight.data, mode='fan_out')
            elif isinstance(m, nn.GroupNorm):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()

    def _make_block(self, block, duplicates, out_channels, stride=1):
        """
        Create Block in ResNet.

        Args:
            block: BasicBlock
            duplicates: number of BasicBlock
            out_channels: out channels of the block

        Returns:
            nn.Sequential(*layers)
        """
        downsample = None
        if (stride != 1) or (self.in_channels != out_channels):
            downsample = nn.Sequential(
                conv3x3(self.in_channels, out_channels, stride=stride),
                nn.GroupNorm(16,out_channels)
            )

        layers = []
        layers.append(
            block(self.in_channels, out_channels, stride, downsample))
        self.in_channels = out_channels
        for _ in range(1, duplicates):
            layers.append(block(out_channels, out_channels))

        return nn.Sequential(*layers)

    def forward(self, x):
        """Forward pass of ResNet."""
        out = self.conv1(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.dropout(out)

        # Stacked Basic Blocks
        out = self.conv2_x(out)
        out = self.bn2_x(out)
        out = self.conv3_x(out)
        out = self.bn3_x(out)
        out = self.conv4_x(out)
        out = self.bn4_x(out)
        out = self.conv5_x(out)
        out = self.bn5_x(out)

        out = self.maxpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc_layer(out)

        return out

# %%
lenet5_cifar100 = ResNet(BasicBlock, [3, 4, 6, 3])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:84: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.

# %%
validate_every = 2000

# %%
lenet5_cifar100_dev = lenet5_cifar100.to(device)
opt = O.SGD(lenet5_cifar100.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-5)
scheduler = O.lr_scheduler.MultiStepLR(opt, milestones=[70, 120],gamma=0.1)
criterion = nn.CrossEntropyLoss(reduction="mean")
train_cross_entropy = []
train_accuracy = []
validation_cross_entropy = []
validation_accuracy = []

best_model_accuracy = 0

for epoch in range(500):
    n_correct = 0
    n_total = 0
    for i, batch in enumerate(cifar100_train_loader):
        x, labels = batch
        x, labels = x.to(device), labels.to(device)
        N = x.shape[0]
        
        # training mode (for things like dropout)
        lenet5_cifar100_dev.train()
        
        # clear previous gradients
        opt.zero_grad()
        
        y_hat = lenet5_cifar100_dev(x)
        loss = criterion(y_hat, labels)
        loss.backward()
        opt.step()
        
        train_cross_entropy.append(loss)
        
        n_correct += (torch.argmax(y_hat, dim=1) == labels).sum().item()
        n_total += N
        
        # evaluation mode (e.g. adds dropped neurons back in)
        lenet5_cifar100_dev.eval()
        if i % validate_every == 0:
            n_val_correct = 0
            n_val_total = 0
            v_cross_entropy_sum = 0
            
            # don't calculate gradients here
            with torch.no_grad():
                for j, v_batch in enumerate(cifar100_test_loader):
                    v_x, v_labels = v_batch
                    v_x, v_labels = v_x.to(device), v_labels.to(device)
                    v_N = v_x.shape[0]
                    
                    v_y_hat = lenet5_cifar100_dev(v_x)
                    v_loss = criterion(v_y_hat, v_labels)
                    v_cross_entropy_sum += v_loss
                    n_val_correct += (torch.argmax(v_y_hat, dim=1) == v_labels).sum().item()
                    n_val_total += v_N

            print(f"[epoch {epoch + 1}, iteration {i}] \t accuracy: {n_val_correct / n_val_total} \t cross entropy: {v_cross_entropy_sum / n_val_total}")
            validation_accuracy.append(n_val_correct / n_val_total)
            validation_cross_entropy.append(v_cross_entropy_sum / n_val_total)
            if n_val_correct / n_val_total >= best_model_accuracy:
                best_model_accuracy = n_val_correct / n_val_total
                print("saving")
                torch.save(lenet5_cifar100_dev.state_dict(), './lenet5_cifar100')
    
    print(f"epoch {epoch + 1} accumulated train accuracy: {n_correct / n_total}")
    train_accuracy.append(n_correct / n_total)
# Out:
# [epoch 1, iteration 0] 	 accuracy: 0.0103 	 cross entropy: 0.019892722368240356
# saving
# epoch 1 accumulated train accuracy: 0.04442
# [epoch 2, iteration 0] 	 accuracy: 0.0954 	 cross entropy: 0.015949029475450516
# saving
# epoch 2 accumulated train accuracy: 0.12324
# [epoch 3, iteration 0] 	 accuracy: 0.1496 	 cross entropy: 0.014441457577049732
# saving
# epoch 3 accumulated train accuracy: 0.17832
# [epoch 4, iteration 0] 	 accuracy: 0.1918 	 cross entropy: 0.013542759232223034
# saving
# epoch 4 accumulated train accuracy: 0.2167
# [epoch 5, iteration 0] 	 accuracy: 0.2102 	 cross entropy: 0.013136721216142178
# saving
# epoch 5 accumulated train accuracy: 0.24926
# [epoch 6, iteration 0] 	 accuracy: 0.2528 	 cross entropy: 0.012179569341242313
# saving
# epoch 6 accumulated train accuracy: 0.27732
# [epoch 7, iteration 0] 	 accuracy: 0.2718 	 cross entropy: 0.01192521583288908
# saving
# epoch 7 accumulated train accuracy: 0.30632
# [epoch 8, iteration 0] 	 accuracy: 0.2885 	 cross entropy: 0.01159703265875578
# saving
# epoch 8 accumulated train accuracy: 0.33278
# [epoch 9, iteration 0] 	 accuracy: 0.3211 	 cross entropy: 0.010816521011292934
# saving
# epoch 9 accumulated train accuracy: 0.3631
# [epoch 10, iteration 0] 	 accuracy: 0.3208 	 cross entropy: 0.010939606465399265
# epoch 10 accumulated train accuracy: 0.39168
# [epoch 11, iteration 0] 	 accuracy: 0.3483 	 cross entropy: 0.010294632986187935
# saving
# epoch 11 accumulated train accuracy: 0.41786
# [epoch 12, iteration 0] 	 accuracy: 0.3859 	 cross entropy: 0.009524080902338028
# saving
# epoch 12 accumulated train accuracy: 0.43748
# [epoch 13, iteration 0] 	 accuracy: 0.404 	 cross entropy: 0.00897880271077156
# saving
# epoch 13 accumulated train accuracy: 0.45584
# [epoch 14, iteration 0] 	 accuracy: 0.4269 	 cross entropy: 0.00870586559176445
# saving
# epoch 14 accumulated train accuracy: 0.478
# [epoch 15, iteration 0] 	 accuracy: 0.4335 	 cross entropy: 0.008594218641519547
# saving
# epoch 15 accumulated train accuracy: 0.48894
# [epoch 16, iteration 0] 	 accuracy: 0.4286 	 cross entropy: 0.008751868270337582
# epoch 16 accumulated train accuracy: 0.51134
# [epoch 17, iteration 0] 	 accuracy: 0.4561 	 cross entropy: 0.008211186155676842
# saving
# epoch 17 accumulated train accuracy: 0.5254
# [epoch 18, iteration 0] 	 accuracy: 0.4447 	 cross entropy: 0.008327611722052097
# epoch 18 accumulated train accuracy: 0.53936
# [epoch 19, iteration 0] 	 accuracy: 0.4883 	 cross entropy: 0.007675557397305965
# saving
# epoch 19 accumulated train accuracy: 0.55482
# [epoch 20, iteration 0] 	 accuracy: 0.4863 	 cross entropy: 0.007708667777478695
# epoch 20 accumulated train accuracy: 0.57022
# [epoch 21, iteration 0] 	 accuracy: 0.4934 	 cross entropy: 0.007575421128422022
# saving
# epoch 21 accumulated train accuracy: 0.57598
# [epoch 22, iteration 0] 	 accuracy: 0.4878 	 cross entropy: 0.007612032815814018
# epoch 22 accumulated train accuracy: 0.58866
# [epoch 23, iteration 0] 	 accuracy: 0.5094 	 cross entropy: 0.007345748599618673
# saving
# epoch 23 accumulated train accuracy: 0.60256
# [epoch 24, iteration 0] 	 accuracy: 0.525 	 cross entropy: 0.006916162557899952
# saving
# epoch 24 accumulated train accuracy: 0.61558
# [epoch 25, iteration 0] 	 accuracy: 0.5274 	 cross entropy: 0.006959316786378622
# saving
# epoch 25 accumulated train accuracy: 0.6229
# [epoch 26, iteration 0] 	 accuracy: 0.5173 	 cross entropy: 0.007271358277648687
# epoch 26 accumulated train accuracy: 0.63202
# [epoch 27, iteration 0] 	 accuracy: 0.532 	 cross entropy: 0.00690698204562068
# saving
# epoch 27 accumulated train accuracy: 0.64178
# [epoch 28, iteration 0] 	 accuracy: 0.5365 	 cross entropy: 0.006868679076433182
# saving
# epoch 28 accumulated train accuracy: 0.65612
# [epoch 29, iteration 0] 	 accuracy: 0.5474 	 cross entropy: 0.006694231182336807
# saving
# epoch 29 accumulated train accuracy: 0.66134
# [epoch 30, iteration 0] 	 accuracy: 0.5508 	 cross entropy: 0.006693928502500057
# saving
# epoch 30 accumulated train accuracy: 0.6711
# [epoch 31, iteration 0] 	 accuracy: 0.5487 	 cross entropy: 0.006549799349159002
# epoch 31 accumulated train accuracy: 0.67764
# [epoch 32, iteration 0] 	 accuracy: 0.5437 	 cross entropy: 0.006801240146160126
# epoch 32 accumulated train accuracy: 0.68884
# [epoch 33, iteration 0] 	 accuracy: 0.5495 	 cross entropy: 0.006700861733406782
# epoch 33 accumulated train accuracy: 0.69798
# [epoch 34, iteration 0] 	 accuracy: 0.5496 	 cross entropy: 0.006826290860772133
# epoch 34 accumulated train accuracy: 0.70294
# [epoch 35, iteration 0] 	 accuracy: 0.5636 	 cross entropy: 0.006629015784710646
# saving
# epoch 35 accumulated train accuracy: 0.71096
# [epoch 36, iteration 0] 	 accuracy: 0.5558 	 cross entropy: 0.006684048101305962
# epoch 36 accumulated train accuracy: 0.72132
# [epoch 37, iteration 0] 	 accuracy: 0.5759 	 cross entropy: 0.00638241833075881
# saving
# epoch 37 accumulated train accuracy: 0.72834
# [epoch 38, iteration 0] 	 accuracy: 0.5623 	 cross entropy: 0.006706858519464731
# epoch 38 accumulated train accuracy: 0.73358
# [epoch 39, iteration 0] 	 accuracy: 0.5605 	 cross entropy: 0.006658440921455622
# epoch 39 accumulated train accuracy: 0.7356
# [epoch 40, iteration 0] 	 accuracy: 0.5744 	 cross entropy: 0.006422467529773712
# epoch 40 accumulated train accuracy: 0.74914
# [epoch 41, iteration 0] 	 accuracy: 0.5839 	 cross entropy: 0.0062338984571397305
# saving
# epoch 41 accumulated train accuracy: 0.75838
# [epoch 42, iteration 0] 	 accuracy: 0.5893 	 cross entropy: 0.006198904477059841
# saving
# epoch 42 accumulated train accuracy: 0.76676
# [epoch 43, iteration 0] 	 accuracy: 0.5819 	 cross entropy: 0.00648277485743165
# epoch 43 accumulated train accuracy: 0.76954
# [epoch 44, iteration 0] 	 accuracy: 0.5741 	 cross entropy: 0.006512901280075312
# epoch 44 accumulated train accuracy: 0.77522
# [epoch 45, iteration 0] 	 accuracy: 0.5818 	 cross entropy: 0.006492838263511658
# epoch 45 accumulated train accuracy: 0.7771
# [epoch 46, iteration 0] 	 accuracy: 0.5919 	 cross entropy: 0.006346892565488815
# saving
# epoch 46 accumulated train accuracy: 0.78586
# [epoch 47, iteration 0] 	 accuracy: 0.5897 	 cross entropy: 0.0062755984254181385
# epoch 47 accumulated train accuracy: 0.79526
# [epoch 48, iteration 0] 	 accuracy: 0.5796 	 cross entropy: 0.006606972310692072
# epoch 48 accumulated train accuracy: 0.80306
# [epoch 49, iteration 0] 	 accuracy: 0.5863 	 cross entropy: 0.006591061130166054
# epoch 49 accumulated train accuracy: 0.81154
# [epoch 50, iteration 0] 	 accuracy: 0.6002 	 cross entropy: 0.006219651084393263
# saving
# epoch 50 accumulated train accuracy: 0.8189
# [epoch 51, iteration 0] 	 accuracy: 0.5872 	 cross entropy: 0.0066004409454762936
# epoch 51 accumulated train accuracy: 0.81796
# [epoch 52, iteration 0] 	 accuracy: 0.593 	 cross entropy: 0.006607532501220703
# epoch 52 accumulated train accuracy: 0.82934
# [epoch 53, iteration 0] 	 accuracy: 0.6028 	 cross entropy: 0.0062729837372899055
# saving
# epoch 53 accumulated train accuracy: 0.83402
# [epoch 54, iteration 0] 	 accuracy: 0.6018 	 cross entropy: 0.006342438980937004
# epoch 54 accumulated train accuracy: 0.83732
# [epoch 55, iteration 0] 	 accuracy: 0.6082 	 cross entropy: 0.0064216903410851955
# saving
# epoch 55 accumulated train accuracy: 0.84376
# [epoch 56, iteration 0] 	 accuracy: 0.603 	 cross entropy: 0.006453076843172312
# epoch 56 accumulated train accuracy: 0.85172
# [epoch 57, iteration 0] 	 accuracy: 0.6047 	 cross entropy: 0.006483672186732292
# epoch 57 accumulated train accuracy: 0.85616
# [epoch 58, iteration 0] 	 accuracy: 0.6058 	 cross entropy: 0.0065605794079601765
# epoch 58 accumulated train accuracy: 0.85644
# [epoch 59, iteration 0] 	 accuracy: 0.5998 	 cross entropy: 0.006716499105095863
# epoch 59 accumulated train accuracy: 0.86112
# [epoch 60, iteration 0] 	 accuracy: 0.611 	 cross entropy: 0.006362970918416977
# saving
# epoch 60 accumulated train accuracy: 0.8703
# [epoch 61, iteration 0] 	 accuracy: 0.6045 	 cross entropy: 0.006654687225818634
# epoch 61 accumulated train accuracy: 0.87256
# [epoch 62, iteration 0] 	 accuracy: 0.6123 	 cross entropy: 0.006496095098555088
# saving
# epoch 62 accumulated train accuracy: 0.87778
# [epoch 63, iteration 0] 	 accuracy: 0.5963 	 cross entropy: 0.006978693883866072
# epoch 63 accumulated train accuracy: 0.88142
# [epoch 64, iteration 0] 	 accuracy: 0.5955 	 cross entropy: 0.006893603131175041
# epoch 64 accumulated train accuracy: 0.8916
# [epoch 65, iteration 0] 	 accuracy: 0.6048 	 cross entropy: 0.006697710137814283
# epoch 65 accumulated train accuracy: 0.89398
# [epoch 66, iteration 0] 	 accuracy: 0.6027 	 cross entropy: 0.006853483617305756
# epoch 66 accumulated train accuracy: 0.89474
# [epoch 67, iteration 0] 	 accuracy: 0.6102 	 cross entropy: 0.006670037750154734
# epoch 67 accumulated train accuracy: 0.90196
# [epoch 68, iteration 0] 	 accuracy: 0.6138 	 cross entropy: 0.006678243167698383
# saving
# epoch 68 accumulated train accuracy: 0.90794
# [epoch 69, iteration 0] 	 accuracy: 0.6141 	 cross entropy: 0.006783897057175636
# saving
# epoch 69 accumulated train accuracy: 0.90604
# [epoch 70, iteration 0] 	 accuracy: 0.6255 	 cross entropy: 0.006657408084720373
# saving
# epoch 70 accumulated train accuracy: 0.90704
# [epoch 71, iteration 0] 	 accuracy: 0.6216 	 cross entropy: 0.0066560180857777596
# epoch 71 accumulated train accuracy: 0.91432
# [epoch 72, iteration 0] 	 accuracy: 0.6236 	 cross entropy: 0.006649768445640802
# epoch 72 accumulated train accuracy: 0.9179
# [epoch 73, iteration 0] 	 accuracy: 0.6213 	 cross entropy: 0.006631642114371061
# epoch 73 accumulated train accuracy: 0.91768
# [epoch 74, iteration 0] 	 accuracy: 0.5977 	 cross entropy: 0.0072635868564248085
# epoch 74 accumulated train accuracy: 0.92146
# [epoch 75, iteration 0] 	 accuracy: 0.6139 	 cross entropy: 0.0070181675255298615
# epoch 75 accumulated train accuracy: 0.92324
# [epoch 76, iteration 0] 	 accuracy: 0.6189 	 cross entropy: 0.006965415086597204
# epoch 76 accumulated train accuracy: 0.92932
# [epoch 77, iteration 0] 	 accuracy: 0.6175 	 cross entropy: 0.0069363974034786224
# epoch 77 accumulated train accuracy: 0.93522
# [epoch 78, iteration 0] 	 accuracy: 0.6199 	 cross entropy: 0.006973559502512217
# epoch 78 accumulated train accuracy: 0.93348
# [epoch 79, iteration 0] 	 accuracy: 0.6217 	 cross entropy: 0.00703527731820941
# epoch 79 accumulated train accuracy: 0.93694
# [epoch 80, iteration 0] 	 accuracy: 0.6258 	 cross entropy: 0.0068453834392130375
# saving
# epoch 80 accumulated train accuracy: 0.94004
# [epoch 81, iteration 0] 	 accuracy: 0.6256 	 cross entropy: 0.00707703223451972
# epoch 81 accumulated train accuracy: 0.94054
# [epoch 82, iteration 0] 	 accuracy: 0.6213 	 cross entropy: 0.0071243285201489925
# epoch 82 accumulated train accuracy: 0.94424
# [epoch 83, iteration 0] 	 accuracy: 0.6279 	 cross entropy: 0.00702492892742157
# saving
# epoch 83 accumulated train accuracy: 0.94858
# [epoch 84, iteration 0] 	 accuracy: 0.6235 	 cross entropy: 0.007243023719638586
# epoch 84 accumulated train accuracy: 0.9523
# [epoch 85, iteration 0] 	 accuracy: 0.6325 	 cross entropy: 0.007010174449533224
# saving
# epoch 85 accumulated train accuracy: 0.94878
# [epoch 86, iteration 0] 	 accuracy: 0.618 	 cross entropy: 0.007551016751676798
# epoch 86 accumulated train accuracy: 0.94962
# [epoch 87, iteration 0] 	 accuracy: 0.6172 	 cross entropy: 0.007373076397925615
# epoch 87 accumulated train accuracy: 0.95478
# [epoch 88, iteration 0] 	 accuracy: 0.6294 	 cross entropy: 0.007026132196187973
# epoch 88 accumulated train accuracy: 0.95384
# [epoch 89, iteration 0] 	 accuracy: 0.6182 	 cross entropy: 0.007430817000567913
# epoch 89 accumulated train accuracy: 0.95608
# [epoch 90, iteration 0] 	 accuracy: 0.6273 	 cross entropy: 0.00729616591706872
# epoch 90 accumulated train accuracy: 0.95838
# [epoch 91, iteration 0] 	 accuracy: 0.6275 	 cross entropy: 0.007191271986812353
# epoch 91 accumulated train accuracy: 0.9618
# [epoch 92, iteration 0] 	 accuracy: 0.634 	 cross entropy: 0.007213071919977665
# saving
# epoch 92 accumulated train accuracy: 0.96658
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-196d97196c4c> in <module>()
#      48                     v_N = v_x.shape[0]
#      49
# ---> 50                     v_y_hat = lenet5_cifar100_dev(v_x)
#      51                     v_loss = criterion(v_y_hat, v_labels)
#      52                     v_cross_entropy_sum += v_loss
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-30-49e5f964f057> in forward(self, x)
#     119     def forward(self, x):
#     120         """Forward pass of ResNet."""
# --> 121         out = self.conv1(x)
#     122         out = self.bn(out)
#     123         out = self.relu(out)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     347
#     348     def forward(self, input):
# --> 349         return self._conv_forward(input, self.weight)
#     350
#     351 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     344                             _pair(0), self.dilation, self.groups)
#     345         return F.conv2d(input, weight, self.bias, self.stride,
# --> 346                         self.padding, self.dilation, self.groups)
#     347
#     348     def forward(self, input):
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/signal_handling.py in handler(signum, frame)
#      64         # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65         # Python can still get and update the process status successfully.
# ---> 66         _error_if_any_worker_fails()
#      67         if previous_handler is not None:
#      68             previous_handler(signum, frame)
#
# RuntimeError: DataLoader worker (pid 10578) is killed by signal: Killed.

# %%
plt.title('Group normalization loss')
#plt.plot(train_cross_entropy)
plt.plot(validation_cross_entropy)
plt.show()

# %%
plt.title('Group normalization loss')
plt.plot(train_cross_entropy)
#plt.plot(validation_cross_entropy)
plt.show()

# %%
plt.title('Group normalization accuracy')
plt.plot(train_accuracy)
plt.plot(validation_accuracy)
plt.show()
